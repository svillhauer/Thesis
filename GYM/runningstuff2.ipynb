# %%
from PIL import Image
im = Image.open("varying_currents.gif")
print("Animated:", getattr(im, "is_animated", False))
print("Frames:", getattr(im, "n_frames", 1))
# Out:
# Animated: True
# Frames: 120

# %%
from IPython.display import Image, display
display(Image(filename="varying_currents.gif"))
